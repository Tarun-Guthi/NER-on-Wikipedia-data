# %% [markdown]
# <h2><span style="color:red">Problem Statement</span></h2>
#
# 1. Scrap data using wikipedia API to perform NER
#
#
# 2. Perform text pre-processing before named entity recognition
#
#
#
# 3. Perform Named Entity Recognition on scrapped data and extract entities like city, person, organization, Date, Geographical Entity, Product etc.
#
#
#
# **Sample Output-**
#
# [https://lh5.googleusercontent.com/qZdi5Xs2zpAsDztHZOwaMe5pflEs5TTRTx5xZSSgi-60D6IdTzR6iVOqMY4o0YztPPAk-hFqBivTyL5g_YZY55OO-TlTjPR5une9lE317c8Fw-EPeUlek0Es-LWZaxEeISYOwTKV](https://lh5.googleusercontent.com/qZdi5Xs2zpAsDztHZOwaMe5pflEs5TTRTx5xZSSgi-60D6IdTzR6iVOqMY4o0YztPPAk-hFqBivTyL5g_YZY55OO-TlTjPR5une9lE317c8Fw-EPeUlek0Es-LWZaxEeISYOwTKV)
#
#
#
#
# 4. Display annotated text in Streamlit App and also display the occurrence of each label in a text in Bar graph form.
#
#
#
# 5. Implement token based authentication technique to secure API endpoints.
#
#
# 6. Please complete this assignment using Python & Flask. Feel free to use any Python packages as you see fit.
#
#
#
# 7. The code and API endpoint should be production ready and hosted somewhere in a publicly accessible location like on AWS, Heroku, PythonAnywhere, etc.

# %% [markdown]
# <h2><span style="color:violet">Sample Output</span></h2>

# %%
from IPython.display import Image
from IPython.core.display import HTML 
Image(url= "https://lh5.googleusercontent.com/qZdi5Xs2zpAsDztHZOwaMe5pflEs5TTRTx5xZSSgi-60D6IdTzR6iVOqMY4o0YztPPAk-hFqBivTyL5g_YZY55OO-TlTjPR5une9lE317c8Fw-EPeUlek0Es-LWZaxEeISYOwTKV")
# Out:
# <img src="https://lh5.googleusercontent.com/qZdi5Xs2zpAsDztHZOwaMe5pflEs5TTRTx5xZSSgi-60D6IdTzR6iVOqMY4o0YztPPAk-hFqBivTyL5g_YZY55OO-TlTjPR5une9lE317c8Fw-EPeUlek0Es-LWZaxEeISYOwTKV"/>

# %% [markdown]
# <h2><span style="color:green"> Problem Approach </span></h2>

# %% [markdown]
# # Importing required libraries

# %%
import spacy_streamlit
import wikipediaapi
import streamlit as st
import spacy
from spacy_streamlit import visualize_ner
from spacy import displacy
import en_core_web_sm
import re
import pandas as pd
from collections import Counter, defaultdict
import srsly
from dframcy import DframCy

# %%
#st.title("NER on Wikipedia data") #Title 

topic = st.text_input("Enter the topic you want to search", "  ")  #user input

wiki = wikipediaapi.Wikipedia(
        language='en',
        extract_format=wikipediaapi.ExtractFormat.WIKI      # choose English as language and format is wiki
)
# Out:
# Enter the topic you want to searchdhoni

# %%
data = (wiki.page(topic).text) # Extract wikipedia page whole text data 

data  # print the data
# Out:
# 2021-03-07 14:26:18.439 INFO    wikipediaapi: Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=dhoni&explaintext=1&exsectionformat=wiki
# ...

# %% [markdown]
# ## Observation(s):
#
# * The above extracted data has many special charecters and sysmbols.
#
#
#
# * We need to perform text-preprocessing on these data.

# %% [markdown]
# #  Text pre-processing

# %%
data = re.sub('[^a-zA-Z0-9 \n\.]', '', data) # substitute all the special charecters symbols with a space

data = re.sub(r'\s+'," ", data)

data = data.lower()  # lowering the words

# %%
print(data)  # data after pre-processing
# Out:
# mahendra singh dhoni pronunciation born 7 july 1981 is a former indian international cricketer who captained the indian national team in limitedovers formats from 2007 to 2017 and in test cricket from 2008 to 2014. under his captaincy india won the inaugural 2007 icc world twenty20 the 2010 and 2016 asia cups the 2011 icc cricket world cup and the 2013 icc champions trophy. a righthanded middleorder batsman and wicketkeeper dhoni is one of the highest run scorers in one day internationals odis with more than 10000 runs scored and is considered an effective finisher in limitedovers formats. he is widely regarded as one of the greatest wicketkeeper batsmen and captains in the history of the game. he was also the first wicketkeeper to effect 100 stumpings in odi cricket.dhoni made his odi debut on 23 december 2004 against bangladesh and played his first test a year later against sri lanka. he has been the recipient of many awards including the icc odi player of the year award in 2008 an
# ...

# %% [markdown]
# ## Applying NER on the data

# %%
nlp = spacy.load("en_core_web_sm")   #load the pre trained model

doc = nlp(data)  #applying the package on the data

visualize_ner(doc, show_table= True ,labels=nlp.get_pipe("ner").labels) #visualize NER on data

st.success("Success")  

dframcy = DframCy(nlp)  

token_annotation_dataframe, entity_dataframe = dframcy.to_dataframe(doc, separate_entity_dframe=True)  #to dataframe

st.subheader("Bar chart for occurrence of each label in a text") # Subheader 

st.bar_chart(entity_dataframe['ent_text'])  #Bar chart for annoted text
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     mahendra singh dhoni
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  pronunciation born
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     7 july 1981
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  is a former
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     indian
# ...

# %% [markdown]
# ## Observation(s):
#
# * It performed pretty good on the extracted data.
